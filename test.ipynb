# %%
li = [1,'asdf',2.34,43,'dragon']
li.append('cat')
print(li)
li.remove('cat')
print(li)
li.pop()
print(li)
li[1:3]
# Out:
# [1, 'asdf', 2.34, 43, 'dragon', 'cat']
# [1, 'asdf', 2.34, 43, 'dragon']
# [1, 'asdf', 2.34, 43]
# ['asdf', 2.34]
