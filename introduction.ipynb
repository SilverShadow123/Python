# %%
from operator import truediv

from parso.python.tree import String
from seaborn import dogplot

print('hello', 'dragon','ball', sep='-')
# Out:
# hello-dragon-ball

# %%
x =10
y = 5.6
name = 'dragon'
print(x + y)
print(name)
# Out:
# 15.6
# dragon

# %%
type(name)
# Out:
# str

# %%
is_true = True
#Use snake case
my_name ='Seaum'
my_name
# Out:
# 'Seaum'

# %%
age = 2
Age = 3
age == Age
# Out:
# False

# %%
age =55
a= float(age)
b= int(age)
c= str(age)
a,b,c
# Out:
# (55.0, 55, '55')

# %%
a=15//4
print(a)
# Out:
# 3

# %%
x='5'
y=2
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 x='5'
#       2 y=2
# ----> 3 print(x+y)
#
# TypeError: can only concatenate str (not "int") to str
